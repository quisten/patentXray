# %% [markdown]
# # PatentDatabase Comparative Debugging

# %%
# Import and selection of files
import pandas as pd

df_A = pd.read_csv("Runs/Oct-18_Threshold_100_Full/crawlerALL_translated.csv", index_col=[0], encoding="utf-8")

df_A.head()
# Out:
#              patentID                                    Title  \
# Index
# 0      US2021055580A1        Transparent phase change actuator
# 1      WO2020107985A1  Imaging module and electronic apparatus
# 2        CN213426288U         Tlens camera module and terminal
# 3         EP3896954A1       Camera assembly and user equipment
# 4      US2021318509A1            Lens module and camera module
#
#                                                 Inventor  \
# Index
# 0      Spencer Allan Wells|Katherine Marie Smyth|Andr...
# 1                                                 韦怡|陈嘉伟
# 2                           卢江|李廷飞|赵军|谢双燕|齐书|晏政波|陈国狮|古昌根
# 3      Chuan YANG|Li-Te Kuo|Ming Zhou|Liang Li|Qianya...
# 4                                            Jae Woo JUN
#
#                                        Assignee  Score Publication_Date  \
# Index
# 0                     Facebook Technologies Llc    -10       2021-02-25
# ...
